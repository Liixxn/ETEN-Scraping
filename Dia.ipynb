# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

#Se inicializa el dataframe de los productos en oferta
df = pd.DataFrame(columns=['nombre', 'precio_anterior', 'precio_actual'])
url = "https://www.dia.es/compra-online/ofertas-DIA-online"
header = {
    'User-Agent': 'Chrome 108.0.5359.125',
    'Accept-Language': 'es'
}
words = ['/bebidas/', '/frescos/', '/congelados/', '/despensa/', '/bodega/', '/platos-preparados/']
#Contador de pagina
pagina_actual = 1
#Array de urls de las paginas de ofertas de dia
urls = [url]
#Array nombre y precio de productos
productos_temp = []

while urls:
    
    url_actual = urls.pop(0)
    response = requests.get(url_actual, headers=header)
    soup_dia = BeautifulSoup(response.content, 'html.parser')
    productos = soup_dia.find_all('div', class_="product-list__item")
    #Se recorren los productos
    for product in productos:
        #Se recorren las palabras clave
        for word in words:
            #Si el enlace del producto contiene una palabra clave
            if word in product.find('a').get('href'):
                #Se buscan el nombre y el precio de los productos y se introducen en productos_temp
                nombre = product.find('span', class_='details').text.strip()
                precio = product.find('p', class_='price').text.strip()
                print(nombre, precio)
                productos_temp.append({'nombre': nombre, 'precio': precio})
               
    #Paginación
    pagina_actual += 1
    url_actual = url + f'?q=%3Arelevance&page={pagina_actual}'
    response = requests.get(url_actual, headers=header)
    #Si la url da respuesta, se añade al array de urls
    if response.status_code == 200:
        urls.append(url_actual)
#Se recorre el array de productos
for producto in productos_temp:
    precios = producto['precio'].split('€')
    #Si el producto tiene dos precios (no es oferta 2x1)
    if len(precios) == 2:
        #Se consigue el valor del precio anterior y del actual y se añaden al dataframe junto al nombre
        precio_anterior = precios[0].strip()
        precio_actual = precios[1].strip()
        df = df.append({'nombre': producto['nombre'], 'precio_anterior': precio_anterior, 'precio_actual': precio_actual}, ignore_index=True)
# Out:
# LAY'S 3 D's bugles bolsa 33 gr 0,65 €
# FRIT RAVICH  mix frutos secos bolsa 300 gr 2,90 €
# ROCKSTAR bebida energética rockstar lata 50 cl 1,50 €
# SELECCIÓN DE DIA filete de cinta de lomo marinado bandeja 300 gr 2,49 €
# 1,99 €
# DANONE ACTIVIA bífidus cremoso de frutas silvestres 0% pack 4 unidades 120 gr 2,69 €
# 2,39 €
# SPRITE lata 33 cl 0,53 €
# 0,43 €
# FERRERO ROCHER bombones caja 200 gr 5,29 €
# 3,70 €
# FERRERO rocher bombones caja 375 gr 9,39 €
# 6,57 €
# MON CHERI bombones de chocolate con cereza caja 315 gr 7,89 €
# 5,52 €
# BONDUELLE guisantes extra finos frasco 465 gr 3,49 €
# FERRERO rocher bombones caja 300 gr 8,99 €
# 6,29 €
# MARCILLA café molido natural gran aroma paquete 250 gr 3,20 €
# MARCILLA cafe molido mezcla gran aroma paquete 250 gr 3,20 €
# FERRERO ROCHER bombones pack 3 unidades envase 35 gr 1,50 €
# 1,05 €
# RED BULL bebida energética pack 4 latas 25 cl 4,99 €
# RUFFLES patatas fritas onduladas sabor a jamón bolsa 275 gr 3,39 €
# ...
